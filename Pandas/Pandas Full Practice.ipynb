# %% [markdown]
# # Introduction to Pandas
#
# In this section of the course we will learn how to use pandas for data analysis. You can think of pandas as an extremely powerful version of Excel, with a lot more features. In this section of the course, you should go through the notebooks in this order:
#
# * Data Input and Output
# * Series
# * DataFrames
# * Operations
# * GroupBy
# * Missing Data
# * Date and Time
# * Merging,Joining,and Concatenating
# * Ploting

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading Data from file, Url, Excel

# %%
df = pd.read_csv('titanic.csv')
df1 = pd.read_excel('train.xlsx', sheet_name='Sheet1')

# %%
df2 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass        Name  \
# 0            1         0       3     "Braund
# 1            2         1       1    "Cumings
# 2            3         1       3  "Heikkinen
# 3            4         1       1   "Futrelle
# 4            5         0       3      "Allen
#
#                                             Sex     Age  SibSp  Parch  Ticket  \
# 0                              Mr. Owen Harris"    male   22.0      1       0
# 1   Mrs. John Bradley (Florence Briggs Thayer)"  female   38.0      1       0
# 2                                  Miss. Laina"  female   26.0      0       0
# 3           Mrs. Jacques Heath (Lily May Peel)"  female   35.0      1       0
# 4                            Mr. William Henry"    male   35.0      0       0
#
#            Ticket.1     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
type(df2) #list
df2[0].head()
# Out:
#     Season   Age                                   Team  \
# 0  2008-09  19.0  Did Not Play (other pro league—Spain)
# 1  2009-10  20.0                                    OKC
# 2  2010-11  21.0                                    OKC
# 3  2011-12  22.0                                    OKC
# 4  2012-13  23.0                                    OKC
#
#                                       Lg  \
# 0  Did Not Play (other pro league—Spain)
# 1                                    NBA
# 2                                    NBA
# 3                                    NBA
# 4                                    NBA
#
#                                      Pos  \
# 0  Did Not Play (other pro league—Spain)
# 1                                     PF
# 2                                     PF
# 3                                     PF
# 4                                     PF
#
#                                        G  \
# 0  Did Not Play (other pro league—Spain)
# ...

# %%
df4 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])
df4
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %% [markdown]
# ## Saving Data Into File

# %%
'''
pd.to_csv('file_name',index = False)
pd.to_excel('file_name', Sheet_name = 'Sheet1')
'''
# Out:
# "\npd.to_csv('file_name',index = False)\npd.to_excel('file_name', Sheet_name = 'Sheet1')\n"

# %% [markdown]
# ## Getting Information About Datafram

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#            Ticket        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes == 'object'
# Out:
# Unnamed: 0     False
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
[df.dtypes[df.dtypes == 'object']]
# Out:
# [Name        object
#  Sex         object
#  Ticket      object
#  Cabin       object
#  Embarked    object
#  dtype: object]

# %%
df3 = df[df.dtypes[df.dtypes == 'object'].index]

# %%
df3.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %% [markdown]
# ## Selection of Column And Rows In DataFrame

# %%
#Column
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df[['Name', 'Ticket']].head()
# Out:
#                                                 Name            Ticket
# 0                            Braund, Mr. Owen Harris         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                             Heikkinen, Miss. Laina  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                           Allen, Mr. William Henry            373450

# %%
df[2:7:2]
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass                      Name  \
# 2           2            3         1       3    Heikkinen, Miss. Laina
# 4           4            5         0       3  Allen, Mr. William Henry
# 6           6            7         0       1   McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
# 6    male  54.0      0      0             17463  51.8625   E46        S

# %%
#Row selection Based on index label
df.loc[2]
# Out:
# Unnamed: 0                          2
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.loc[[2,3,4]]
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
#Selection Based on index position
df.iloc[[10,12]]
# Out:
#     Unnamed: 0  PassengerId  Survived  Pclass  \
# 10          10           11         1       3
# 12          12           13         0       3
#
#                                Name     Sex   Age  SibSp  Parch     Ticket  \
# 10  Sandstrom, Miss. Marguerite Rut  female   4.0      1      1    PP 9549
# 12   Saundercock, Mr. William Henry    male  20.0      0      0  A/5. 2151
#
#      Fare Cabin Embarked
# 10  16.70    G6        S
# 12   8.05   NaN        S

# %%
#select ON Both Rows and Columns
df.loc[[2,3,4],['Name','Pclass','Sex','Age']]
# Out:
#                                            Name  Pclass     Sex   Age
# 2                        Heikkinen, Miss. Laina       3  female  26.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 4                      Allen, Mr. William Henry       3    male  35.0

# %% [markdown]
# Selection Based on Condition

# %%
df1[df1['Fare'] == max(df1['Fare'])]
# Out:
#      PassengerId  Survived  Pclass      Name                          Sex  \
# 258          259         1       1     "Ward                  Miss. Anna"
# 679          680         1       1  "Cardeza   Mr. Thomas Drake Martinez"
# 737          738         1       1  "Lesurer               Mr. Gustave J"
#
#         Age  SibSp  Parch  Ticket  Ticket.1      Fare        Cabin Embarked
# 258  female   35.0      0       0  PC 17755  512.3292          NaN        C
# 679    male   36.0      0       1  PC 17755  512.3292  B51 B53 B55        C
# 737    male   35.0      0       0  PC 17755  512.3292         B101        C

# %%
df1[df1['Ticket']>1].head()
# Out:
#     PassengerId  Survived  Pclass        Name  \
# 8             9         1       3    "Johnson
# 13           14         0       3  "Andersson
# 25           26         1       3    "Asplund
# 27           28         0       1    "Fortune
# 43           44         1       2    "Laroche
#
#                                                   Sex     Age  SibSp  Parch  \
# 8           Mrs. Oscar W (Elisabeth Vilhelmina Berg)"  female   27.0      0
# 13                                  Mr. Anders Johan"    male   39.0      1
# 25   Mrs. Carl Oscar (Selma Augusta Emilia Johanss...  female   38.0      1
# 27                             Mr. Charles Alexander"    male   19.0      3
# 43                   Miss. Simonne Marie Anne Andree"  female    3.0      1
#
#     Ticket       Ticket.1      Fare        Cabin Embarked
# 8        2         347742   11.1333          NaN        S
# 13       5         347082   31.2750          NaN        S
# ...

# %%
df1[df1['Ticket']>1][['Name','PassengerId']].head()
# Out:
#           Name  PassengerId
# 8     "Johnson            9
# 13  "Andersson           14
# 25    "Asplund           26
# 27    "Fortune           28
# 43    "Laroche           44

# %%
df1[(df1['Ticket']>3) & (df1['Fare']>10)]
# Out:
#      PassengerId  Survived  Pclass        Name  \
# 13            14         0       3  "Andersson
# 25            26         1       3    "Asplund
# 167          168         0       3      "Skoog
# 360          361         0       3      "Skoog
# 438          439         0       1    "Fortune
# 567          568         0       3    "Palsson
# 610          611         0       3  "Andersson
# 638          639         0       3     "Panula
# 678          679         0       3    "Goodwin
# 885          886         0       3       "Rice
#
#                                                    Sex     Age  SibSp  Parch  \
# 13                                   Mr. Anders Johan"    male   39.0      1
# 25    Mrs. Carl Oscar (Selma Augusta Emilia Johanss...  female   38.0      1
# 167          Mrs. William (Anna Bernhardina Karlsson)"  female   45.0      1
# 360                                       Mr. Wilhelm"    male   40.0      1
# ...

# %%
df1[(df1['Ticket']>3) & (df1['Fare']>10)][['Name','Age','Sex','Fare']].tail(7)
# Out:
#            Name     Age                                               Sex  \
# 360      "Skoog    male                                      Mr. Wilhelm"
# 438    "Fortune    male                                         Mr. Mark"
# 567    "Palsson  female               Mrs. Nils (Alma Cornelia Berglund)"
# 610  "Andersson  female   Mrs. Anders Johan (Alfrida Konstantia Brogren)"
# 638     "Panula  female                   Mrs. Juha (Maria Emilia Ojala)"
# 678    "Goodwin  female                   Mrs. Frederick (Augusta Tyler)"
# 885       "Rice  female                   Mrs. William (Margaret Norton)"
#
#          Fare
# 360   27.9000
# 438  263.0000
# 567   21.0750
# 610   31.2750
# 638   39.6875
# 678   46.9000
# 885   29.1250

# %%
df1[df1['Fare'].between(50,100)]
# Out:
#      PassengerId  Survived  Pclass         Name  \
# 1              2         1       1     "Cumings
# 3              4         1       1    "Futrelle
# 6              7         0       1    "McCarthy
# 34            35         0       1       "Meyer
# 35            36         0       1   "Holverson
# ..           ...       ...     ...          ...
# 849          850         1       1  "Goldenberg
# 863          864         0       3        "Sage
# 867          868         0       1    "Roebling
# 871          872         1       1    "Beckwith
# 879          880         1       1      "Potter
#
#                                               Sex     Age  SibSp  Parch  \
# 1     Mrs. John Bradley (Florence Briggs Thayer)"  female   38.0      1
# 3             Mrs. Jacques Heath (Lily May Peel)"  female   35.0      1
# 6                                  Mr. Timothy J"    male   54.0      0
# 34                              Mr. Edgar Joseph"    male   28.0      1
# ...

# %%
df1.sort_values('SibSp')
# Out:
#      PassengerId  Survived  Pclass            Name  \
# 803          804         1       3         "Thomas
# 755          756         1       2     "Hamalainen
# 644          645         1       3        "Baclini
# 469          470         1       3        "Baclini
# 78            79         1       2       "Caldwell
# ..           ...       ...     ...             ...
# 859          860         0       3           "Razi
# 863          864         0       3           "Sage
# 868          869         0       3  "van Melkebeke
# 878          879         0       3         "Laleff
# 888          889         0       3       "Johnston
#
#                                     Sex     Age  SibSp  Parch  Ticket  \
# 803            Master. Assad Alexander"    male   0.42      0       1
# 755                      Master. Viljo"    male   0.67      1       1
# 644                      Miss. Eugenie"  female   0.75      2       1
# ...

# %% [markdown]
# ## Operations On index

# %%
df4 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])
df4
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
#New index Values
l = ['x','y','z','v']
df4['new'] = l
df4.set_index('new', inplace=True)
df4
# Out:
#       A   B   C   D
# new
# x    A0  B0  C0  D0
# y    A1  B1  C1  D1
# z    A2  B2  C2  D2
# v    A3  B3  C3  D3

# %%
l = ['e0','e1','e2','e3']
df4['E'] = l
df4
# Out:
#       A   B   C   D   E
# new
# x    A0  B0  C0  D0  e0
# y    A1  B1  C1  D1  e1
# z    A2  B2  C2  D2  e2
# v    A3  B3  C3  D3  e3

# %%
df4.rename(columns={'E':'G'}, inplace=True)
df4
# Out:
#       A   B   C   D   G
# new
# x    A0  B0  C0  D0  e0
# y    A1  B1  C1  D1  e1
# z    A2  B2  C2  D2  e2
# v    A3  B3  C3  D3  e3

# %%
df4.drop('G', axis=1 ,inplace=True)

# %%
df4
# Out:
#       A   B   C   D
# new
# x    A0  B0  C0  D0
# y    A1  B1  C1  D1
# z    A2  B2  C2  D2
# v    A3  B3  C3  D3

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      object
#  1   B       4 non-null      object
#  2   C       4 non-null      object
#  3   D       4 non-null      object
# dtypes: object(4)
# memory usage: 160.0+ bytes

# %%
df4.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df4.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df4.values
# Out:
# array([['A0', 'B0', 'C0', 'D0'],
#        ['A1', 'B1', 'C1', 'D1'],
#        ['A2', 'B2', 'C2', 'D2'],
#        ['A3', 'B3', 'C3', 'D3']], dtype=object)

# %%
df4.shape
# Out:
# (4, 4)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass        Name  \
# 0            1         0       3     "Braund
# 1            2         1       1    "Cumings
# 2            3         1       3  "Heikkinen
# 3            4         1       1   "Futrelle
# 4            5         0       3      "Allen
#
#                                             Sex     Age  SibSp  Parch  Ticket  \
# 0                              Mr. Owen Harris"    male   22.0      1       0
# 1   Mrs. John Bradley (Florence Briggs Thayer)"  female   38.0      1       0
# 2                                  Miss. Laina"  female   26.0      0       0
# 3           Mrs. Jacques Heath (Lily May Peel)"  female   35.0      1       0
# 4                            Mr. William Henry"    male   35.0      0       0
#
#            Ticket.1     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df1['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
pd.Categorical(df1['Embarked'])
# Out:
# [S, C, S, S, S, ..., S, S, S, C, Q]
# Length: 891
# Categories (3, object): [C, Q, S]

# %%
s = df1['Embarked'][df1['Embarked'].isnull() == True]

# %%
len(s.index)
# Out:
# 2

# %%
df1.iloc[s.index]
# Out:
#      PassengerId  Survived  Pclass    Name  \
# 61            62         1       1  "Icard
# 829          830         1       1  "Stone
#
#                                       Sex     Age  SibSp  Parch  Ticket  \
# 61                          Miss. Amelie"  female   38.0      0       0
# 829   Mrs. George Nelson (Martha Evelyn)"  female   62.0      0       0
#
#     Ticket.1  Fare Cabin Embarked
# 61    113572  80.0   B28      NaN
# 829   113572  80.0   B28      NaN

# %% [markdown]
# ## Mathematical Computetion With Dataframe

# %%
df1
# Out:
#      PassengerId  Survived  Pclass        Name  \
# 0              1         0       3     "Braund
# 1              2         1       1    "Cumings
# 2              3         1       3  "Heikkinen
# 3              4         1       1   "Futrelle
# 4              5         0       3      "Allen
# ..           ...       ...     ...         ...
# 886          887         0       2   "Montvila
# 887          888         1       1     "Graham
# 888          889         0       3   "Johnston
# 889          890         1       1       "Behr
# 890          891         0       3     "Dooley
#
#                                               Sex     Age  SibSp  Parch  \
# 0                                Mr. Owen Harris"    male   22.0      1
# 1     Mrs. John Bradley (Florence Briggs Thayer)"  female   38.0      1
# 2                                    Miss. Laina"  female   26.0      0
# 3             Mrs. Jacques Heath (Lily May Peel)"  female   35.0      1
# ...

# %%
df1.sort_values(by='Name')
# Out:
#      PassengerId  Survived  Pclass            Name  \
# 845          846         0       3         "Abbing
# 279          280         1       3         "Abbott
# 746          747         0       3         "Abbott
# 874          875         1       2        "Abelson
# 308          309         0       2        "Abelson
# ..           ...       ...     ...             ...
# 286          287         1       3      "de Mulder
# 282          283         0       3  "de Pelsmaeker
# 361          362         0       2      "del Carlo
# 153          154         0       3   "van Billiard
# 868          869         0       3  "van Melkebeke
#
#                                 Sex     Age  SibSp  Parch  Ticket  \
# 845                    Mr. Anthony"    male   42.0      0       0
# 279       Mrs. Stanton (Rosa Hunt)"  female   35.0      1       1
# 746            Mr. Rossmore Edward"    male   16.0      1       1
# 874   Mrs. Samuel (Hannah Wizosky)"  female   28.0      1       0
# ...

# %%
#count Non Null observation
df1.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          714
# Parch          891
# Ticket         891
# Ticket.1       891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
#sum of values
df1.sum()
# Out:
# PassengerId                                               397386
# Survived                                                     342
# Pclass                                                      2057
# Name           "Braund"Cumings"Heikkinen"Futrelle"Allen"Moran...
# Sex             Mr. Owen Harris" Mrs. John Bradley (Florence ...
# Age            malefemalefemalefemalemalemalemalemalefemalefe...
# SibSp                                                    21205.2
# Parch                                                        466
# Ticket                                                       340
# Fare                                                     28693.9
# dtype: object

# %%
#Mean of values
df1.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# SibSp           29.699118
# Parch            0.523008
# Ticket           0.381594
# Fare            32.204208
# dtype: float64

# %%
#Arithmetic Median of values
df1.median()
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# SibSp           28.0000
# Parch            0.0000
# Ticket           0.0000
# Fare            14.4542
# dtype: float64

# %%
#Arithmetic Absolute Deviation
df1.mad()
# Out:
# PassengerId    222.749719
# Survived         0.473013
# Pclass           0.761968
# SibSp           11.322944
# Parch            0.713780
# Ticket           0.580742
# Fare            28.163692
# dtype: float64

# %%
#Minimum
df1.min()
# Out:
# PassengerId                         1
# Survived                            0
# Pclass                              1
# Name                          "Abbing
# Sex             Capt. Edward Gifford"
# Age                            female
# SibSp                            0.42
# Parch                               0
# Ticket                              0
# Fare                                0
# dtype: object

# %%
#Maximum
df1.max()
# Out:
# PassengerId                                                  891
# Survived                                                       1
# Pclass                                                         3
# Name                                              "van Melkebeke
# Sex             the Countess. of (Lucy Noel Martha Dyer-Edwar...
# Age                                                         male
# SibSp                                                         80
# Parch                                                          8
# Ticket                                                         6
# Fare                                                     512.329
# dtype: object

# %%
df5 = pd.DataFrame({'a':[1,2,3,4,5],
       'b':[-1,-2,-3,-4,-5],
       'c':[6,7,8,9,10]})
df5
# Out:
#    a  b   c
# 0  1 -1   6
# 1  2 -2   7
# 2  3 -3   8
# 3  4 -4   9
# 4  5 -5  10

# %%
#Product of values
df5.prod()
# Out:
# a      120
# b     -120
# c    30240
# dtype: int64

# %%
#Samole kurtosis fourth Movement
df5.kurt()
# Out:
# a   -1.2
# b   -1.2
# c   -1.2
# dtype: float64

# %%
#Samole Skewness third Movement
df5.skew()
# Out:
# a    0.0
# b    0.0
# c    0.0
# dtype: float64

# %%
df5['a'] + df5['c']
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
df5['a'].add(df5['c'])
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %% [markdown]
# #Apply function to each value of series or dataframe

# %%
def squre(x):
    return x*2

# %%
#lambda Function
a = lambda x: x*2

# %%
#Apply function to series
df5['a'].apply(squre)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# Name: a, dtype: int64

# %%
df5['a'].apply(a)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# Name: a, dtype: int64

# %%
#Apply function to Dataframe
df5.applymap(squre)
# Out:
#     a   b   c
# 0   2  -2  12
# 1   4  -4  14
# 2   6  -6  16
# 3   8  -8  18
# 4  10 -10  20

# %% [markdown]
# ## Group By

# %%
df6 = pd.DataFrame({'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
 'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
 'Sales':[200,120,340,124,243,350]})
df6
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
#** Now you can use the .groupby() method to group rows together based off of a column name.
#For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

by_comp = df6.groupby("Company")
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %% [markdown]
# ## Missing Data

# %%
import numpy as np
df7 = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})
df7
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
#Drop all NaN values
df7.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
#Drop NaN Values Based on Thresh value
df7.dropna(axis=1, thresh=2)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3

# %%
#NaN value fill by value
df7.fillna(value='x')
# Out:
#    A  B  C
# 0  1  5  1
# 1  2  x  2
# 2  x  x  3

# %%
df7['B'].fillna(value=df7['B'].mean())
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# Name: B, dtype: float64

# %% [markdown]
# ## Date & Time in Dataframe

# %%
# importing pandas as pd
import pandas as pd

# Creating the dataframe
df8 = pd.DataFrame({'Date':['11/8/2011', '04/23/2008', '10/2/2019'],
				'Event':['Music', 'Poetry', 'Theatre'],
				'Cost':[10000, 5000, 15000]})

# Print the dataframe
print(df8)

# Now we will check the data type
# of the 'Date' column
df8.info()
# Out:
#          Date    Event   Cost
# 0   11/8/2011    Music  10000
# 1  04/23/2008   Poetry   5000
# 2   10/2/2019  Theatre  15000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      object
#  1   Event   3 non-null      object
#  2   Cost    3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df8['Date'] = pd.to_datetime(df8['Date'])
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      datetime64[ns]
#  1   Event   3 non-null      object
#  2   Cost    3 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 200.0+ bytes

# %%
# importing pandas library
import pandas as pd

# Initializing the nested list with Data set
player_list = [['20200712',50000,'20200812'],
			['20200714',51000,'20200814'],
			['20200716',51500,'20200816'],
			['20200719',53000,'20200819'],
			['20200721',54000,'20200821'],
			['20200724',55000,'20200824'],
			['20200729',57000,'20200824']]

# creating a pandas dataframe
df9 = pd.DataFrame(
player_list,columns = ['Treatment_start',
						'No.of Patients',
						'Treatment_end'])

# printing dataframe
print(df9)

# checking the type
print(df9.dtypes)
# Out:
#   Treatment_start  No.of Patients Treatment_end
# 0        20200712           50000      20200812
# 1        20200714           51000      20200814
# 2        20200716           51500      20200816
# 3        20200719           53000      20200819
# 4        20200721           54000      20200821
# 5        20200724           55000      20200824
# 6        20200729           57000      20200824
# Treatment_start    object
# No.of Patients      int64
# Treatment_end      object
# dtype: object

# %%
df9
# Out:
#   Treatment_start  No.of Patients Treatment_end
# 0        20200712           50000      20200812
# 1        20200714           51000      20200814
# 2        20200716           51500      20200816
# 3        20200719           53000      20200819
# 4        20200721           54000      20200821
# 5        20200724           55000      20200824
# 6        20200729           57000      20200824

# %%
df9['Treatment_start'] = pd.to_datetime(df9['Treatment_start'], format='%Y%m%d')

df9['Treatment_end'] = pd.to_datetime(df9['Treatment_end'], format='%Y%m%d')

# %%
df9
# Out:
#   Treatment_start  No.of Patients Treatment_end
# 0      2020-07-12           50000    2020-08-12
# 1      2020-07-14           51000    2020-08-14
# 2      2020-07-16           51500    2020-08-16
# 3      2020-07-19           53000    2020-08-19
# 4      2020-07-21           54000    2020-08-21
# 5      2020-07-24           55000    2020-08-24
# 6      2020-07-29           57000    2020-08-24

# %% [markdown]
# ## Merge, Join & Concatenation

# %% [markdown]
# ### Merge

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1']})

left
# Out:
#     A   B key1 key2
# 0  A0  B0   K0   K0
# 1  A1  B1   K0   K1
# 2  A2  B2   K1   K0
# 3  A3  B3   K2   K1

# %%
right = pd.DataFrame({'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3'],
                      'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0']})
right
# Out:
#     C   D key1 key2
# 0  C0  D0   K0   K0
# 1  C1  D1   K1   K0
# 2  C2  D2   K1   K0
# 3  C3  D3   K2   K0

# %%
#By Default Its Inner join
pd.merge(left, right, on='key1')
# Out:
#     A   B key1 key2_x   C   D key2_y
# 0  A0  B0   K0     K0  C0  D0     K0
# 1  A1  B1   K0     K1  C0  D0     K0
# 2  A2  B2   K1     K0  C1  D1     K0
# 3  A2  B2   K1     K0  C2  D2     K0
# 4  A3  B3   K2     K1  C3  D3     K0

# %%
pd.merge(left, right, on = ['key1', 'key2'])
# Out:
#     A   B key1 key2   C   D
# 0  A0  B0   K0   K0  C0  D0
# 1  A2  B2   K1   K0  C1  D1
# 2  A2  B2   K1   K0  C2  D2

# %%
#Outer join
pd.merge(left, right, how='outer',on = ['key1', 'key2'])
# Out:
#      A    B key1 key2    C    D
# 0   A0   B0   K0   K0   C0   D0
# 1   A1   B1   K0   K1  NaN  NaN
# 2   A2   B2   K1   K0   C1   D1
# 3   A2   B2   K1   K0   C2   D2
# 4   A3   B3   K2   K1  NaN  NaN
# 5  NaN  NaN   K2   K0   C3   D3

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])
# Out:
#      A    B key1 key2   C   D
# 0   A0   B0   K0   K0  C0  D0
# 1   A2   B2   K1   K0  C1  D1
# 2   A2   B2   K1   K0  C2  D2
# 3  NaN  NaN   K2   K0  C3  D3

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#     A   B key1 key2    C    D
# 0  A0  B0   K0   K0   C0   D0
# 1  A1  B1   K0   K1  NaN  NaN
# 2  A2  B2   K1   K0   C1   D1
# 3  A2  B2   K1   K0   C2   D2
# 4  A3  B3   K2   K1  NaN  NaN

# %%
#markdown cell and write
#![](image_name.jpg)

# %% [markdown]
# ![](Pandas_merg.png)

# %% [markdown]
# ### Concatenation

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# ### Concatenation

# %%
pd.concat([left,right])
# Out:
#       A    B    C    D
# K0   A0   B0  NaN  NaN
# K1   A1   B1  NaN  NaN
# K2   A2   B2  NaN  NaN
# K0  NaN  NaN   C0   D0
# K2  NaN  NaN   C2   D2
# K3  NaN  NaN   C3   D3

# %%
pd.concat([left, right], axis=1)
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# ## Ploting with Series and Dataframe

# %%
#Ploting with series
df1['PassengerId'].plot()

# %%
#ploting with dataframe
df1.plot()

# %%
#ploting with dataframe
df1[['PassengerId', 'Fare']].plot()

# %%
df1[['PassengerId', 'Fare']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B435749C8>,
# ...
#       dtype=object)

# %%
graf = df1[['PassengerId', 'Fare']].plot()
graf.set_xlabel('X_Axis')
graf.set_ylabel('Y_Axis')
graf.set_label('Train_Dataset')

# %%
df1[['PassengerId', 'Fare']].plot.bar()

# %%
df1[['PassengerId', 'Fare']].plot.hist()
